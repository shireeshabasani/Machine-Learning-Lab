# %% [markdown]
# Decision Tree
#
# Tiatnic Survival Dataset

# %%
# import pandas as pd 

df=pd.read_csv('train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Import the Necessary Libraries
import pandas as pd

# %%
#Load the data sets- train and test 
# Import necessary libraries
import pandas as pd

# Load the train dataset
train_df = pd.read_csv('train.csv')

# Display basic information about the dataset
print(train_df.info())

# Display the first 5 rows
print(train_df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
# ...

# %%
#Look at top values of train data 
print(train_df.head(10))
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
#Print the column names of train data
print(train_df.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#Print the dimension of train and test data
# Print the dimension (rows, columns) of the train dataset
print("Train Data Dimensions:", train_df.shape)

# Load the test dataset
test_df = pd.read_csv('train.csv')

# Print the dimension (rows, columns) of the test dataset
print("Test Data Dimensions:", test_df.shape)
# Out:
# Train Data Dimensions: (891, 12)
# Test Data Dimensions: (891, 12)

# %%
#Print the number of missing values in each column of train and test data
# Print the number of missing values in each column of the train dataset
print("Missing values in Train Data:")
print(train_df.isnull().sum())

# Load the test dataset
test_df = pd.read_csv('train.csv')

# Print the number of missing values in each column of the test dataset
print("\nMissing values in Test Data:")
print(test_df.isnull().sum())
# Out:
# Missing values in Train Data:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
#
# Missing values in Test Data:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## Data Visualization

# %%
 import matplotlib.pyplot as plt
import seaborn as sns

# Set plot style
sns.set_style("whitegrid")

# Create subplots
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# Plot bar charts
sns.countplot(x='Survived', data=train_df, ax=axes[0, 0])
axes[0, 0].set_title('Survival Count')

sns.countplot(x='Pclass', data=train_df, ax=axes[0, 1])
axes[0, 1].set_title('Passenger Class Count')

sns.countplot(x='Sex', data=train_df, ax=axes[1, 0])
axes[1, 0].set_title('Gender Count')

sns.countplot(x='Embarked', data=train_df, ax=axes[1, 1])
axes[1, 1].set_title('Embarked Port Count')

# Show plots
plt.tight_layout()
plt.show()

# %%
#Histogram of Age, Parch, Fare
import matplotlib.pyplot as plt
import seaborn as sns

# Set up the plot for 3 subplots
plt.figure(figsize=(18, 5))

# Histogram for Age
plt.subplot(1, 3, 1)
sns.histplot(df['Age'].dropna(), kde=True, color='skyblue')
plt.title('Histogram of Age')

# Histogram for Parch
plt.subplot(1, 3, 2)
sns.histplot(df['Parch'], kde=True, color='lightgreen')
plt.title('Histogram of Parch')

# Histogram for Fare
plt.subplot(1, 3, 3)
sns.histplot(df['Fare'], kde=True, color='lightcoral')
plt.title('Histogram of Fare')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
#Plot histogram of age for survived and did not survived class
import matplotlib.pyplot as plt
import seaborn as sns

# Set up the plot
plt.figure(figsize=(10, 6))

# Plot for Survived (Survived = 1)
sns.histplot(df[df['Survived'] == 1]['Age'].dropna(), kde=True, color='skyblue', label='Survived', bins=20)

# Plot for Did Not Survive (Survived = 0)
sns.histplot(df[df['Survived'] == 0]['Age'].dropna(), kde=True, color='lightcoral', label='Did Not Survive', bins=20)

# Adding titles and labels
plt.title('Histogram of Age for Survived and Did Not Survive')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.legend()

# Show plot
plt.show()

# %%
#Count class and geder wise survival rate - plot with appropriate chart
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the survival rate based on Class and Gender
survival_rate = df.groupby(['Pclass', 'Sex'])['Survived'].mean().reset_index()

# Set up the plot
plt.figure(figsize=(10, 6))

# Plot the survival rate using a bar plot
sns.barplot(x='Pclass', y='Survived', hue='Sex', data=survival_rate, palette='muted')

# Adding titles and labels
plt.title('Survival Rate by Class and Gender')
plt.xlabel('Class')
plt.ylabel('Survival Rate')

# Show the plot
plt.show()

#Age wise Distribution of Male and Female passengers
import matplotlib.pyplot as plt
import seaborn as sns

# Set up the plot
plt.figure(figsize=(10, 6))

# Plot for Male passengers
sns.histplot(df[df['Sex'] == 'male']['Age'].dropna(), kde=True, color='lightblue', label='Male', bins=20)

# Plot for Female passengers
sns.histplot(df[df['Sex'] == 'female']['Age'].dropna(), kde=True, color='lightpink', label='Female', bins=20)

# Adding titles and labels
plt.title('Age-wise Distribution of Male and Female Passengers')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.legend()

# Show plot
plt.show()

# %%
#Histogram of Age of the given data set(sample)
import matplotlib.pyplot as plt
import seaborn as sns

# Set up the plot
plt.figure(figsize=(10, 6))

# Plot histogram for Age column
sns.histplot(df['Age'].dropna(), kde=True, color='skyblue', bins=20)

# Adding titles and labels
plt.title('Histogram of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')

# Show plot
plt.show()

# %% [markdown]
# ## Handling Missing Values

# %%
#Replace the msiing values in Embarked column by 'S'
# Check the missing values before replacement
print("Before replacement:")
print(df['Embarked'].isnull().sum())

# Replace missing values in the 'Embarked' column with 'S'
df['Embarked'] = df['Embarked'].fillna('S')

# Check the missing values after replacement
print("After replacement:")
print(df['Embarked'].isnull().sum())
# Out:
# Before replacement:
# 0
# After replacement:
# 0

# %%
#Impute the missing values in Fare column with median value
# Check the missing values before imputation
print("Before imputation:")
print(df['Fare'].isnull().sum())

# Impute missing values in the 'Fare' column with the median value
df['Fare'] = df['Fare'].fillna(df['Fare'].median())

# Check the missing values after imputation
print("After imputation:")
print(df['Fare'].isnull().sum())
# Out:
# Before imputation:
# 0
# After imputation:
# 0

# %%
#Impute the Age column. It has too many missing values but it may be important. 
#We fill the missing values with numbers randomly drawn from distribution
#that has same mean and standard deviation as non missing Age data
# Check the missing values before imputation
print("Before imputation:")
print(df['Age'].isnull().sum())

# Impute missing values in the 'Age' column with random values drawn from a normal distribution
mean_age = df['Age'].mean()
std_age = df['Age'].std()
random_ages = np.random.normal(loc=mean_age, scale=std_age, size=df['Age'].isnull().sum())
df.loc[df['Age'].isnull(), 'Age'] = random_ages

# Check the missing values after imputation
print("After imputation:")
print(df['Age'].isnull().sum())
# Out:
# Before imputation:
# 0
# After imputation:
# 0

# %% [markdown]
# ## Feature Engineering - Creating new features

# %%
# Create and add a new feature FamilySize as a combination of SibSp and Parch
#FamilySize = Parch + SibSp + 1
# Create a new feature 'FamilySize' as a combination of 'SibSp' and 'Parch'
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1

# Print the updated DataFrame
print(df[['SibSp', 'Parch', 'FamilySize']].head())  # Displaying the first few rows for clarity
# Out:
#    SibSp  Parch  FamilySize
# 0      1      0           2
# 1      1      0           2
# 2      0      0           1
# 3      1      0           2
# 4      0      0           1

# %%
# Create new feature IsAlone from FamilySize
#If FamilySize == 1 then IsAlone = True else IsAlone = False
# Create a new feature 'IsAlone' based on 'FamilySize'
df['IsAlone'] = df['FamilySize'].apply(lambda x: True if x == 1 else False)

# Print the updated DataFrame to verify the new feature
print(df[['FamilySize', 'IsAlone']].head())  # Displaying the first few rows for clarity
# Out:
#    FamilySize  IsAlone
# 0           2    False
# 1           2    False
# 2           1     True
# 3           2    False
# 4           1     True

# %% [markdown]
# ## Create a new attribute Has_cabin using the attribue Cabin.
# #if Cabin == NaN the Has_cabin = False else Has_cabin = True

# %%
#Drop the columns which may not be useful in prediction of survival
#Drop PassengerId, Name, Ticket, and Cabin

 # Check if the 'Cabin' column exists before proceeding
if 'Cabin' in df.columns:
    # Create a new feature 'Has_cabin' based on 'Cabin'
    df['Has_cabin'] = df['Cabin'].notna()
    
    # Drop the columns that may not be useful for predicting survival
    df.drop(['PassengerId', 'Name', 'Ticket', 'Cabin'], axis=1, inplace=True)
else:
    print("'Cabin' column not found in the DataFrame.")

# Print the updated DataFrame to verify the changes
print(df.head())
# Out:
# 'Cabin' column not found in the DataFrame.
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked  FamilySize  \
# 0         0       3    male  22.0      1      0   7.2500        S           2
# 1         1       1  female  38.0      1      0  71.2833        C           2
# 2         1       3  female  26.0      0      0   7.9250        S           1
# 3         1       1  female  35.0      1      0  53.1000        S           2
# 4         0       3    male  35.0      0      0   8.0500        S           1
#
#    IsAlone
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True

# %% [markdown]
# ## Model Building

# %%
#Prepare X and y
# Define 'y' as the target variable (Survived)
y = df['Survived']

# Define 'X' as the feature set (all columns except 'Survived')
X = df.drop('Survived', axis=1)

# Print the shapes of X and y to verify
print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (891, 9)
# y shape: (891,)

# %%
# Label encoding of categorical features
from sklearn.preprocessing import LabelEncoder

# Create a LabelEncoder object
le = LabelEncoder()

# List of categorical columns to encode (example columns: Sex, Embarked, etc.)
categorical_columns = ['Sex', 'Embarked', 'Has_cabin']

# Apply label encoding to each categorical column
for col in categorical_columns:
    if col in df.columns:
        df[col] = le.fit_transform(df[col])

# Verify the changes by printing the DataFrame
print(df.head())
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  FamilySize  \
# 0         0       3    1  22.0      1      0   7.2500         2           2
# 1         1       1    0  38.0      1      0  71.2833         0           2
# 2         1       3    0  26.0      0      0   7.9250         2           1
# 3         1       1    0  35.0      1      0  53.1000         2           2
# 4         0       3    1  35.0      0      0   8.0500         2           1
#
#    IsAlone
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True

# %%
# concat df_categorical with original df
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Check if the 'Cabin' column exists and create 'Has_cabin' column
if 'Cabin' in df.columns:
    df['Has_cabin'] = df['Cabin'].notna()  # Creates a boolean column where NaN is False, else True
else:
    print("Cabin column does not exist in the DataFrame")

# List of categorical columns to encode (example columns: Sex, Embarked, Has_cabin)
categorical_columns = ['Sex', 'Embarked', 'Has_cabin']

# Ensure the columns to be encoded exist in the DataFrame
existing_categorical_columns = [col for col in categorical_columns if col in df.columns]

# Create a LabelEncoder object
le = LabelEncoder()

# Create a copy of df to avoid modifying the original df directly
df_categorical = df[existing_categorical_columns].copy()

# Apply label encoding to each categorical column
for col in existing_categorical_columns:
    df_categorical[col] = le.fit_transform(df_categorical[col])

# Concatenate the original df (excluding categorical columns) with df_categorical
df = pd.concat([df.drop(existing_categorical_columns, axis=1), df_categorical], axis=1)

# Print the updated DataFrame to verify the changes
print(df.head())
# Out:
# Cabin column does not exist in the DataFrame
#    Survived  Pclass   Age  SibSp  Parch     Fare  FamilySize  IsAlone  Sex  \
# 0         0       3  22.0      1      0   7.2500           2    False    1
# 1         1       1  38.0      1      0  71.2833           2    False    0
# 2         1       3  26.0      0      0   7.9250           1     True    0
# 3         1       1  35.0      1      0  53.1000           2    False    0
# 4         0       3  35.0      0      0   8.0500           1     True    1
#
#    Embarked
# 0         2
# 1         0
# 2         2
# 3         2
# 4         2

# %%
#Do a pairplot of all features 
import seaborn as sns
import matplotlib.pyplot as plt

# Ensure that all features are numeric, or select only numeric columns
df_numeric = df.select_dtypes(include=['number'])

# Create a pairplot of the numeric features
sns.pairplot(df_numeric)

# Display the plot
plt.show()

# %%
# Splitting the data into train and validation set - 90% train 10% validation
#X_train, X_test, y_train, y_validation
from sklearn.model_selection import train_test_split

# Assuming X and y have been prepared (X is your features, y is your target variable)

# Split the data into 90% training and 10% validation
X_train, X_validation, y_train, y_validation = train_test_split(X, y, test_size=0.1, random_state=42)

# Check the shapes of the resulting datasets
print("X_train shape:", X_train.shape)
print("X_validation shape:", X_validation.shape)
print("y_train shape:", y_train.shape)
print("y_validation shape:", y_validation.shape)
# Out:
# X_train shape: (801, 9)
# X_validation shape: (90, 9)
# y_train shape: (801,)
# y_validation shape: (90,)

# %%
# Create the model
# Fitting the decision tree with default hyperparameters
# Importing decision tree classifier from sklearn library
# Importing the necessary library

# One-Hot Encoding of categorical columns
df_encoded = pd.get_dummies(df, drop_first=True)

# Now you can proceed with model training
X = df_encoded.drop('Survived', axis=1)
y = df_encoded['Survived']

# Split the data into training and validation sets
from sklearn.model_selection import train_test_split
X_train, X_validation, y_train, y_validation = train_test_split(X, y, test_size=0.1, random_state=42)

# Importing and creating the model
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(random_state=42)

# Fit the model to the training data
model.fit(X_train, y_train)

# Check the accuracy of the model on the training and validation data
train_accuracy = model.score(X_train, y_train)
validation_accuracy = model.score(X_validation, y_validation)

# Print the accuracies
print(f"Training accuracy: {train_accuracy}")
print(f"Validation accuracy: {validation_accuracy}")
# Out:
# Training accuracy: 0.9775280898876404
# Validation accuracy: 0.7888888888888889

# %%
from sklearn.preprocessing import LabelEncoder

# Create a copy of df to avoid modifying the original df directly
df_encoded = df.copy()

# Apply label encoding to each categorical column
label_encoder = LabelEncoder()

# List of categorical columns to encode
categorical_columns = df_encoded.select_dtypes(include=['object']).columns

for column in categorical_columns:
    df_encoded[column] = label_encoder.fit_transform(df_encoded[column])

# Now you can proceed with model training
X = df_encoded.drop('Survived', axis=1)
y = df_encoded['Survived']

# Split the data into training and validation sets
from sklearn.model_selection import train_test_split
X_train, X_validation, y_train, y_validation = train_test_split(X, y, test_size=0.1, random_state=42)

# Importing and creating the model
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(random_state=42)

# Fit the model to the training data
model.fit(X_train, y_train)

# Check the accuracy of the model on the training and validation data
train_accuracy = model.score(X_train, y_train)
validation_accuracy = model.score(X_validation, y_validation)

# Print the accuracies
print(f"Training accuracy: {train_accuracy}")
print(f"Validation accuracy: {validation_accuracy}")
# Out:
# Training accuracy: 0.9775280898876404
# Validation accuracy: 0.7888888888888889

# %%
#Print the tree
# Importing required packages for visualization

from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# Plot the decision tree
plt.figure(figsize=(20, 10))  # Adjust the size for better readability
plot_tree(model, filled=True, feature_names=X.columns, class_names=['Not Survived', 'Survived'], rounded=True)
plt.show()

# %%
# plotting tree with max_depth=3
# Importing necessary libraries
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier, plot_tree

# Fitting the decision tree with max_depth=3
model = DecisionTreeClassifier(max_depth=3)
model.fit(X_train, y_train)

# Plotting the decision tree
plt.figure(figsize=(20,10))
plot_tree(model, filled=True, feature_names=X_train.columns, class_names=["Not Survived", "Survived"], rounded=True)
plt.show()

# %% [markdown]
# <img src="tree2.png">

# %%
# Check the evaluation metrics of our default model on validation set - Confusion Matrix, Accuracy, Precision, Recall, F1 score

# Importing classification report and confusion matrix from sklearn metrics

# Making predictions

# Printing classification report
# Importing necessary packages
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

# Making predictions on the validation set
y_pred = model.predict(X_validation)

# Printing the confusion matrix
print("Confusion Matrix:")
print(confusion_matrix(y_validation, y_pred))

# Printing the accuracy score
print("Accuracy Score:", accuracy_score(y_validation, y_pred))

# Printing the precision score
print("Precision Score:", precision_score(y_validation, y_pred))

# Printing the recall score
print("Recall Score:", recall_score(y_validation, y_pred))

# Printing the F1 score
print("F1 Score:", f1_score(y_validation, y_pred))

# Printing the classification report
print("Classification Report:")
print(classification_report(y_validation, y_pred))
# Out:
# Confusion Matrix:
# [[46  8]
#  [ 8 28]]
# Accuracy Score: 0.8222222222222222
# Precision Score: 0.7777777777777778
# Recall Score: 0.7777777777777778
# F1 Score: 0.7777777777777778
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85        54
#            1       0.78      0.78      0.78        36
#
#     accuracy                           0.82        90
#    macro avg       0.81      0.81      0.81        90
# weighted avg       0.82      0.82      0.82        90

# %%
# Printing confusion matrix and accuracy
# Importing the necessary packages
from sklearn.metrics import confusion_matrix, accuracy_score

# Making predictions on the validation set
y_pred = model.predict(X_validation)

# Printing the confusion matrix
print("Confusion Matrix:")
print(confusion_matrix(y_validation, y_pred))

# Printing the accuracy score
accuracy = accuracy_score(y_validation, y_pred)
print("Accuracy Score:", accuracy)
# Out:
# Confusion Matrix:
# [[46  8]
#  [ 8 28]]
# Accuracy Score: 0.8222222222222222
